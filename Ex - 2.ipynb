# %%
#import library
import cv2
import matplotlib.pyplot as plt

# %%
#load the image
image=cv2.imread(r"C:\Users\Admin\CV\New folder\kingfisher bird.jpg")

#display the image
plt.imshow(image)

# %%
#shape
image.shape
# Out:
# (1080, 1920, 3)

# %%
(B,G,R)= image[100,100]
print("B={},G={},R={}".format(B,G,R))
# Out:
# B=4,G=32,R=2

# %%
B=image[100,100,0]
print("B={}".format(B))
# Out:
# B=4

# %%
G=image[100,100,0]
print("G={}".format(G))
# Out:
# G=4

# %%
R=image[100,100,0]
print("R={}".format(R))
# Out:
# R=4

# %%
roi = image[10:255,10:255]
plt.imshow(roi)
